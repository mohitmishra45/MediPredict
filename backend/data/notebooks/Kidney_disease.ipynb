# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\mohit\OneDrive\Desktop\SEMESTER 5\Predictive Analysis Project\Dataset\kidney_disease.csv")
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df=df.drop_duplicates()

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype(str).str.strip()

# %%
df = df.drop('id', axis=1)

# %%
for col in df.select_dtypes(include='number').columns:
    df[col] = df[col].fillna(df[col].mean())

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['classification'] = le.fit_transform(df['classification'])
df['htn'] = le.fit_transform(df['htn'])

# %%
df.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(12, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
X=df[['age', 'sc', 'hemo', 'al', 'sg', 'bu', 'htn']]
y=df['classification']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()
X_train_scaled=mn.fit_transform(X_train)
X_test_scaled=mn.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr=lr.predict(X_test_scaled)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=knn.predict(X_test_scaled)

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train_scaled, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb=nb.predict(X_test_scaled)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='gini',random_state=42)
dt.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt=dt.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, classification_report
print("Accuracy Score for the Models:\n")
acc_lr = accuracy_score(y_test, y_pred_lr) * 100
acc_knn = accuracy_score(y_test, y_pred_knn) * 100
acc_nb = accuracy_score(y_test, y_pred_nb) * 100
acc_dt = accuracy_score(y_test, y_pred_dt) * 100
print("Logistic Regression : {:.3f}%".format(acc_lr))
print("KNN                : {:.3f}%".format(acc_knn))
print("Naive Bayes        : {:.3f}%".format(acc_nb))
print("Decision Tree      : {:.3f}%".format(acc_dt))
print("\nClassification Reports:\n")
print("Logistic Regression:\n", classification_report(y_test, y_pred_lr))
print("KNN:\n", classification_report(y_test, y_pred_knn))
print("Naive Bayes:\n", classification_report(y_test, y_pred_nb))
print("Decision Tree:\n", classification_report(y_test, y_pred_dt))
# Out:
# Accuracy Score for the Models:
#
# Logistic Regression : 96.250%
# KNN                : 97.500%
# Naive Bayes        : 94.375%
# Decision Tree      : 96.875%
#
# Classification Reports:
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       102
#            1       0.92      0.98      0.95        58
#
#     accuracy                           0.96       160
#    macro avg       0.95      0.97      0.96       160
# weighted avg       0.96      0.96      0.96       160
#
# KNN:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       102
#            1       0.95      0.98      0.97        58
#
#     accuracy                           0.97       160
#    macro avg       0.97      0.98      0.97       160
# weighted avg       0.98      0.97      0.98       160
#
# Naive Bayes:
#                precision    recall  f1-score   support
#
# ...

# %%
models = {
    "Logistic Regression": lr,
    "KNN": knn,
    "Naive Bayes": nb,
    "Decision Tree": dt
}

accuracies = {
    "Logistic Regression": acc_lr,
    "KNN": acc_knn,
    "Naive Bayes": acc_nb,
    "Decision Tree": acc_dt
}

best_model_name = max(accuracies, key=accuracies.get)
best_model = models[best_model_name]
best_model_accuracy = accuracies[best_model_name]

print("\nBest Model:", best_model_name)
print("Best Accuracy: {:.3f}%".format(best_model_accuracy))
# Out:
# Best Model: KNN
# Best Accuracy: 97.500%

# %%
print("\nEnter patient values for prediction:")
age  = float(input("Age: "))
sc   = float(input("Serum Creatinine (sc): "))
hemo = float(input("Hemoglobin (hemo): "))
al   = float(input("Albumin (al): "))
sg   = float(input("Specific Gravity (sg): "))
bu   = float(input("Blood Urea (bu): "))
htn_input = input("Hypertension (yes/no): ").strip().lower()
htn = 1 if htn_input == "yes" else 0
# Out:
# Enter patient values for prediction:
# Age:  45
# Serum Creatinine (sc):  54
# Hemoglobin (hemo):  54
# Albumin (al):  25
# Specific Gravity (sg):  26
# Blood Urea (bu):  266
# Hypertension (yes/no):  yes

# %%
user_data = np.array([[age, sc, hemo, al, sg, bu, htn]])
user_data_scaled = mn.transform(user_data)

prediction = best_model.predict(user_data_scaled)

print("\nPrediction Result:")
if prediction[0] == 0:
    print("CKD Detected (Chronic Kidney Disease)")
else:
    print("No CKD (Patient is Healthy)")
# Out:
# Prediction Result:
# CKD Detected (Chronic Kidney Disease)
# C:\Users\mohit\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
